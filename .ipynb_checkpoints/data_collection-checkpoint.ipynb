# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader.data as web
import datetime

# %%
slug = "fed-decision-in-july-181"

url = f"https://gamma-api.polymarket.com/events?slug={slug}"
response = requests.get(url)
data = response.json()

print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "id": "287395",
#     "ticker": "fed-decision-in-july-181",
#     "slug": "fed-decision-in-july-181",
#     "title": "Fed Decision in July?",
#     "description": "The FED interest rates are defined in this market by the upper bound of the target federal funds range. The decisions on the target federal funds range are made by the Federal Open Market Committee (FOMC) meetings.\n\nThis market will resolve to the amount of basis points the upper bound of the target federal funds rate is changed by versus the level it was prior to the Federal Reserve's July 2026 meeting.\n\nIf the target federal funds rate is changed to a level not expressed in the displayed options, the change will be rounded up to the nearest 25 and will resolve to the relevant bracket. (e.g. if there's a cut/increase of 12.5 bps it will be considered to be 25 bps)\n\nThe resolution source for this market is the FOMC\u2019s statement after its meeting scheduled for July 28-29, 2026 according to the official calendar: https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm.\n\nThe level and change of the target federal funds rate is also published at the official website of the Federal Reserve at https://www.federalreserve.gov/monetarypolicy/openmarket.htm.\n\nThis market may resolve as soon as the FOMC\u2019s statement for their July meeting with relevant data is issued. If no statement is released by the end date of the next scheduled meeting, this market will resolve to the \"No change\" bracket.",
#     "resolutionSource": "",
#     "startDate": "2026-03-20T00:12:28.430927Z",
#     "creationDate": "2026-03-20T00:13:40.941223Z",
#     "endDate": "2026-07-29T00:00:00Z",
#     "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/fed-decision-in-september-762-c4RyWuxRPo1L.jpg",
#     "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/fed-decision-in-september-762-c4RyWuxRPo1L.jpg",
#     "active": true,
#     "closed": true,
#     "archived": false,
#     "new": false,
#     "featured": false,
#     "restricted": true,
#     "volume": 143954093.78149703,
#     "openInterest": 41980818.845668,
#     "createdAt": "2026-03-19T20:51:46.126657Z",
#     "updatedAt": "2026-08-13T20:05:59.252549Z",
#     "enableOrderBook": true,
#     "negRisk": true,
#     "negRiskMarketID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#     "commentCount": 1,
#     "markets": [
#       {
#         "id": "1654956",
#         "question": "Will the Fed decrease interest rates by 50+ bps after the July 2026 meeting?",
#         "conditionId": "0x3d675f1c88099a57c12abca632cf926be1bf430125168321de06234e9930fe1a",
#         "slug": "will-the-fed-decrease-interest-rates-by-50-bps-after-the-july-2026-meeting",
#         "endDate": "2026-07-29T00:00:00Z",
#         "startDate": "2026-03-20T00:12:28.430927Z",
#         "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "description": "The FED interest rates are defined in this market by the upper bound of the target federal funds range. The decisions on the target federal funds range are made by the Federal Open Market Committee (FOMC) meetings.\n\nThis market will resolve to the amount of basis points the upper bound of the target federal funds rate is changed by versus the level it was prior to the Federal Reserve's July 2026 meeting.\n\nIf the target federal funds rate is changed to a level not expressed in the displayed options, the change will be rounded up to the nearest 25 and will resolve to the relevant bracket. (e.g. if there's a cut/increase of 12.5 bps it will be considered to be 25 bps)\n\nThe resolution source for this market is the FOMC\u2019s statement after its meeting scheduled for July 28-29, 2026 according to the official calendar: https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm.\n\nThe level and change of the target federal funds rate is also published at the official website of the Federal Reserve at https://www.federalreserve.gov/monetarypolicy/openmarket.htm.\n\nThis market may resolve as soon as the FOMC\u2019s statement for their July meeting with relevant data is issued. If no statement is released by the end date of the next scheduled meeting, this market will resolve to the \"No change\" bracket.",
#         "outcomes": "[\"Yes\", \"No\"]",
#         "outcomePrices": "[\"0\", \"1\"]",
#         "volume": "22015343.545755006",
#         "active": true,
#         "closed": true,
#         "marketMakerAddress": "",
#         "createdAt": "2026-03-19T20:51:47.660082Z",
#         "updatedAt": "2026-07-30T18:10:17.734868Z",
#         "closedTime": "2026-07-29 20:01:42+00",
#         "new": false,
#         "featured": false,
#         "submitted_by": "0x91430CaD2d3975766499717fA0D66A78D814E5c5",
#         "archived": false,
#         "resolvedBy": "0x69c47De9D4D3Dad79590d61b9e05918E03775f24",
#         "restricted": true,
#         "groupItemTitle": "50+ bps decrease",
#         "groupItemThreshold": "0",
#         "questionID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#         "umaEndDate": "2026-07-29T20:01:42Z",
#         "enableOrderBook": true,
#         "orderPriceMinTickSize": 0.001,
#         "orderMinSize": 5,
#         "umaResolutionStatus": "resolved",
#         "volumeNum": 22015343.545755006,
#         "endDateIso": "2026-07-29",
#         "startDateIso": "2026-03-20",
#         "hasReviewedDates": true,
#         "clobTokenIds": "[\"34352156398446436078106018571351437965469399998092625112032289774684767742814\", \"81718924566344342339932153243056822500865643754622838691875214933560980686588\"]",
#         "comboStatus": "disabled",
#         "umaBond": "500",
#         "umaReward": "5",
#         "volumeClob": 22015343.545755006,
#         "makerBaseFee": 1000,
#         "takerBaseFee": 1000,
#         "customLiveness": 0,
#         "acceptingOrders": false,
#         "negRisk": true,
#         "negRiskMarketID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#         "negRiskRequestID": "0xc15947466f68765e11a596a07559afdad9c10b8343a78e03111e4291e7232272",
#         "ready": false,
#         "funded": false,
#         "acceptingOrdersTimestamp": "2026-03-20T00:11:07Z",
#         "cyom": false,
#         "pagerDutyNotificationEnabled": false,
#         "approved": true,
#         "rewardsMinSize": 0,
#         "rewardsMaxSpread": 0,
#         "spread": 0.001,
#         "automaticallyResolved": true,
#         "oneDayPriceChange": -0.001,
#         "oneWeekPriceChange": -0.001,
#         "oneMonthPriceChange": -0.0075,
#         "lastTradePrice": 0.001,
#         "bestAsk": 0.001,
#         "automaticallyActive": true,
#         "clearBookOnStart": true,
#         "showGmpSeries": false,
#         "showGmpOutcome": false,
#         "manualActivation": false,
#         "negRiskOther": false,
#         "umaResolutionStatuses": "[\"proposed\"]",
#         "pendingDeployment": false,
#         "deploying": false,
#         "deployingTimestamp": "2026-03-20T00:09:52.852442Z",
#         "rfqEnabled": false,
#         "holdingRewardsEnabled": false,
#         "feesEnabled": true,
#         "requiresTranslation": false,
#         "feeType": "economics_fees",
#         "feeSchedule": {
#           "exponent": 1,
#           "rate": 0.05,
#           "takerOnly": true,
#           "rebateRate": 0.25
#         },
#         "version": "v1"
#       },
#       {
#         "id": "1654957",
#         "question": "Will the Fed decrease interest rates by 25 bps after the July 2026 meeting?",
#         "conditionId": "0x4ede078cae84a5877ac32d7fb48811e5c23549a1904b7df06ff7935c6d79d831",
#         "slug": "will-the-fed-decrease-interest-rates-by-25-bps-after-the-july-2026-meeting",
#         "endDate": "2026-07-29T00:00:00Z",
#         "startDate": "2026-03-20T00:12:36.429499Z",
#         "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "description": "The FED interest rates are defined in this market by the upper bound of the target federal funds range. The decisions on the target federal funds range are made by the Federal Open Market Committee (FOMC) meetings.\n\nThis market will resolve to the amount of basis points the upper bound of the target federal funds rate is changed by versus the level it was prior to the Federal Reserve's July 2026 meeting.\n\nIf the target federal funds rate is changed to a level not expressed in the displayed options, the change will be rounded up to the nearest 25 and will resolve to the relevant bracket. (e.g. if there's a cut/increase of 12.5 bps it will be considered to be 25 bps)\n\nThe resolution source for this market is the FOMC\u2019s statement after its meeting scheduled for July 28-29, 2026 according to the official calendar: https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm.\n\nThe level and change of the target federal funds rate is also published at the official website of the Federal Reserve at https://www.federalreserve.gov/monetarypolicy/openmarket.htm.\n\nThis market may resolve as soon as the FOMC\u2019s statement for their July meeting with relevant data is issued. If no statement is released by the end date of the next scheduled meeting, this market will resolve to the \"No change\" bracket.",
#         "outcomes": "[\"Yes\", \"No\"]",
#         "outcomePrices": "[\"0\", \"1\"]",
#         "volume": "27994692.422440995",
#         "active": true,
#         "closed": true,
#         "marketMakerAddress": "",
#         "createdAt": "2026-03-19T20:51:48.631797Z",
#         "updatedAt": "2026-07-30T18:34:19.069678Z",
#         "closedTime": "2026-07-29 20:01:42+00",
#         "new": false,
#         "featured": false,
#         "submitted_by": "0x91430CaD2d3975766499717fA0D66A78D814E5c5",
#         "archived": false,
#         "resolvedBy": "0x69c47De9D4D3Dad79590d61b9e05918E03775f24",
#         "restricted": true,
#         "groupItemTitle": "25 bps decrease",
#         "groupItemThreshold": "1",
#         "questionID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3401",
#         "umaEndDate": "2026-07-29T20:01:42Z",
#         "enableOrderBook": true,
#         "orderPriceMinTickSize": 0.001,
#         "orderMinSize": 5,
#         "umaResolutionStatus": "resolved",
#         "volumeNum": 27994692.422440995,
#         "endDateIso": "2026-07-29",
#         "startDateIso": "2026-03-20",
#         "hasReviewedDates": true,
#         "clobTokenIds": "[\"107111506004559425167535337910569809007100298896139468418632748246491535011700\", \"90713175285238837229141362456380660699457701142142655731293716395090014512187\"]",
#         "comboStatus": "disabled",
#         "umaBond": "500",
#         "umaReward": "5",
#         "volumeClob": 27994692.422440995,
#         "makerBaseFee": 1000,
#         "takerBaseFee": 1000,
#         "customLiveness": 0,
#         "acceptingOrders": false,
#         "negRisk": true,
#         "negRiskMarketID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#         "negRiskRequestID": "0xada7a1fb021d3d833517e61f2b66a81c1e8086316b21358bba6b68cf462b5bd2",
#         "ready": false,
#         "funded": false,
#         "acceptingOrdersTimestamp": "2026-03-20T00:11:15Z",
#         "cyom": false,
#         "pagerDutyNotificationEnabled": false,
#         "approved": true,
#         "rewardsMinSize": 59,
#         "rewardsMaxSpread": 3.5,
#         "spread": 0.001,
#         "automaticallyResolved": true,
#         "oneDayPriceChange": -0.001,
#         "oneWeekPriceChange": -0.003,
#         "oneMonthPriceChange": -0.014,
#         "lastTradePrice": 0.001,
#         "bestAsk": 0.001,
#         "automaticallyActive": true,
#         "clearBookOnStart": true,
#         "showGmpSeries": false,
#         "showGmpOutcome": false,
#         "manualActivation": false,
#         "negRiskOther": false,
#         "umaResolutionStatuses": "[\"proposed\"]",
#         "pendingDeployment": false,
#         "deploying": false,
#         "deployingTimestamp": "2026-03-20T00:09:52.854936Z",
#         "rfqEnabled": false,
#         "holdingRewardsEnabled": false,
#         "feesEnabled": true,
#         "requiresTranslation": false,
#         "feeType": "economics_fees",
#         "feeSchedule": {
#           "exponent": 1,
#           "rate": 0.05,
#           "takerOnly": true,
#           "rebateRate": 0.25
#         },
#         "version": "v1"
#       },
#       {
#         "id": "1654958",
#         "question": "Will there be no change in Fed interest rates after the July 2026 meeting?",
#         "conditionId": "0x8bf1c1536ecb1c08fe13c6b71e8ab1f58bf3461c4cb79f5f1679f869a06aef86",
#         "slug": "will-there-be-no-change-in-fed-interest-rates-after-the-july-2026-meeting",
#         "endDate": "2026-07-29T00:00:00Z",
#         "startDate": "2026-03-20T00:12:44.271047Z",
#         "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "description": "The FED interest rates are defined in this market by the upper bound of the target federal funds range. The decisions on the target federal funds range are made by the Federal Open Market Committee (FOMC) meetings.\n\nThis market will resolve to the amount of basis points the upper bound of the target federal funds rate is changed by versus the level it was prior to the Federal Reserve's July 2026 meeting.\n\nIf the target federal funds rate is changed to a level not expressed in the displayed options, the change will be rounded up to the nearest 25 and will resolve to the relevant bracket. (e.g. if there's a cut/increase of 12.5 bps it will be considered to be 25 bps)\n\nThe resolution source for this market is the FOMC\u2019s statement after its meeting scheduled for July 28-29, 2026 according to the official calendar: https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm.\n\nThe level and change of the target federal funds rate is also published at the official website of the Federal Reserve at https://www.federalreserve.gov/monetarypolicy/openmarket.htm.\n\nThis market may resolve as soon as the FOMC\u2019s statement for their July meeting with relevant data is issued. If no statement is released by the end date of the next scheduled meeting, this market will resolve to the \"No change\" bracket.",
#         "outcomes": "[\"Yes\", \"No\"]",
#         "outcomePrices": "[\"1\", \"0\"]",
#         "volume": "40497085.547722004",
#         "active": true,
#         "closed": true,
#         "marketMakerAddress": "",
#         "createdAt": "2026-03-19T20:51:49.341926Z",
#         "updatedAt": "2026-07-30T20:08:17.689196Z",
#         "closedTime": "2026-07-29 20:06:41+00",
#         "new": false,
#         "featured": false,
#         "submitted_by": "0x91430CaD2d3975766499717fA0D66A78D814E5c5",
#         "archived": false,
#         "resolvedBy": "0x69c47De9D4D3Dad79590d61b9e05918E03775f24",
#         "restricted": true,
#         "groupItemTitle": "No change",
#         "groupItemThreshold": "2",
#         "questionID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3402",
#         "umaEndDate": "2026-07-29T20:06:41Z",
#         "enableOrderBook": true,
#         "orderPriceMinTickSize": 0.001,
#         "orderMinSize": 5,
#         "umaResolutionStatus": "resolved",
#         "volumeNum": 40497085.547722004,
#         "endDateIso": "2026-07-29",
#         "startDateIso": "2026-03-20",
#         "hasReviewedDates": true,
#         "clobTokenIds": "[\"111604417349377875799825956621596386269673370070912696668140891647145772186047\", \"36015050921127306245266044699797268780268172446856063291868548314968920497494\"]",
#         "comboStatus": "disabled",
#         "umaBond": "500",
#         "umaReward": "5",
#         "volumeClob": 40497085.547722004,
#         "makerBaseFee": 1000,
#         "takerBaseFee": 1000,
#         "customLiveness": 0,
#         "acceptingOrders": false,
#         "negRisk": true,
#         "negRiskMarketID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#         "negRiskRequestID": "0xc551ccfda4e3fa90ef6f8196ac7c05c08c9d422011fc0f2bc68c80d72883fb04",
#         "ready": false,
#         "funded": false,
#         "acceptingOrdersTimestamp": "2026-03-20T00:11:23Z",
#         "cyom": false,
#         "pagerDutyNotificationEnabled": false,
#         "approved": true,
#         "rewardsMinSize": 200,
#         "rewardsMaxSpread": 4.5,
#         "spread": 0.001,
#         "automaticallyResolved": true,
#         "oneDayPriceChange": 0.231,
#         "oneWeekPriceChange": 0.233,
#         "oneMonthPriceChange": 0.1945,
#         "lastTradePrice": 0.999,
#         "bestBid": 0.999,
#         "bestAsk": 1,
#         "automaticallyActive": true,
#         "clearBookOnStart": true,
#         "showGmpSeries": false,
#         "showGmpOutcome": false,
#         "manualActivation": false,
#         "negRiskOther": false,
#         "umaResolutionStatuses": "[\"proposed\"]",
#         "pendingDeployment": false,
#         "deploying": false,
#         "deployingTimestamp": "2026-03-20T00:09:52.856362Z",
#         "rfqEnabled": false,
#         "holdingRewardsEnabled": false,
#         "feesEnabled": true,
#         "requiresTranslation": false,
#         "feeType": "economics_fees",
#         "feeSchedule": {
#           "exponent": 1,
#           "rate": 0.05,
#           "takerOnly": true,
#           "rebateRate": 0.25
#         },
#         "version": "v1"
#       },
#       {
#         "id": "1654959",
#         "question": "Will the Fed increase interest rates by 25 bps after the July 2026 meeting?",
#         "conditionId": "0xb5c0abeecb5502e6e8d83155c27819174d8317af3c425c3afc5a8c45257a3793",
#         "slug": "will-the-fed-increase-interest-rates-by-25-bps-after-the-july-2026-meeting",
#         "endDate": "2026-07-29T00:00:00Z",
#         "startDate": "2026-03-20T00:12:51.189884Z",
#         "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "description": "The FED interest rates are defined in this market by the upper bound of the target federal funds range. The decisions on the target federal funds range are made by the Federal Open Market Committee (FOMC) meetings.\n\nThis market will resolve to the amount of basis points the upper bound of the target federal funds rate is changed by versus the level it was prior to the Federal Reserve's July 2026 meeting.\n\nIf the target federal funds rate is changed to a level not expressed in the displayed options, the change will be rounded up to the nearest 25 and will resolve to the relevant bracket. (e.g. if there's a cut/increase of 12.5 bps it will be considered to be 25 bps)\n\nThe resolution source for this market is the FOMC\u2019s statement after its meeting scheduled for July 28-29, 2026 according to the official calendar: https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm.\n\nThe level and change of the target federal funds rate is also published at the official website of the Federal Reserve at https://www.federalreserve.gov/monetarypolicy/openmarket.htm.\n\nThis market may resolve as soon as the FOMC\u2019s statement for their July meeting with relevant data is issued. If no statement is released by the end date of the next scheduled meeting, this market will resolve to the \"No change\" bracket.",
#         "outcomes": "[\"Yes\", \"No\"]",
#         "outcomePrices": "[\"0\", \"1\"]",
#         "volume": "25890005.575899016",
#         "active": true,
#         "closed": true,
#         "marketMakerAddress": "",
#         "createdAt": "2026-03-19T20:51:50.165369Z",
#         "updatedAt": "2026-07-30T20:02:18.951133Z",
#         "closedTime": "2026-07-29 20:01:42+00",
#         "new": false,
#         "featured": false,
#         "submitted_by": "0x91430CaD2d3975766499717fA0D66A78D814E5c5",
#         "archived": false,
#         "resolvedBy": "0x69c47De9D4D3Dad79590d61b9e05918E03775f24",
#         "restricted": true,
#         "groupItemTitle": "25 bps increase",
#         "groupItemThreshold": "3",
#         "questionID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3403",
#         "umaEndDate": "2026-07-29T20:01:42Z",
#         "enableOrderBook": true,
#         "orderPriceMinTickSize": 0.001,
#         "orderMinSize": 5,
#         "umaResolutionStatus": "resolved",
#         "volumeNum": 25890005.575899016,
#         "endDateIso": "2026-07-29",
#         "startDateIso": "2026-03-20",
#         "hasReviewedDates": true,
#         "clobTokenIds": "[\"10547381015916960267379463101229159185405356924982461726471550099674011526491\", \"102979714187432523726496609637889951679226430871494531752837414533106422105296\"]",
#         "comboStatus": "disabled",
#         "umaBond": "500",
#         "umaReward": "5",
#         "volumeClob": 25890005.575899016,
#         "makerBaseFee": 1000,
#         "takerBaseFee": 1000,
#         "customLiveness": 0,
#         "acceptingOrders": false,
#         "negRisk": true,
#         "negRiskMarketID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#         "negRiskRequestID": "0x3934303b3997937f1665091e62818ba3e2b31b9a65d3318b3c7769b73f87492c",
#         "ready": false,
#         "funded": false,
#         "acceptingOrdersTimestamp": "2026-03-20T00:11:29Z",
#         "cyom": false,
#         "pagerDutyNotificationEnabled": false,
#         "approved": true,
#         "rewardsMinSize": 200,
#         "rewardsMaxSpread": 4.5,
#         "spread": 0.001,
#         "automaticallyResolved": true,
#         "oneDayPriceChange": -0.229,
#         "oneWeekPriceChange": -0.225,
#         "oneMonthPriceChange": -0.176,
#         "lastTradePrice": 0.001,
#         "bestAsk": 0.001,
#         "automaticallyActive": true,
#         "clearBookOnStart": true,
#         "showGmpSeries": false,
#         "showGmpOutcome": false,
#         "manualActivation": false,
#         "negRiskOther": false,
#         "umaResolutionStatuses": "[\"proposed\"]",
#         "pendingDeployment": false,
#         "deploying": false,
#         "deployingTimestamp": "2026-03-20T00:09:52.858264Z",
#         "rfqEnabled": false,
#         "holdingRewardsEnabled": false,
#         "feesEnabled": true,
#         "requiresTranslation": false,
#         "feeType": "economics_fees",
#         "feeSchedule": {
#           "exponent": 1,
#           "rate": 0.05,
#           "takerOnly": true,
#           "rebateRate": 0.25
#         },
#         "version": "v1"
#       },
#       {
#         "id": "1654960",
#         "question": "Will the Fed increase interest rates by 50+ bps after the July 2026 meeting?",
#         "conditionId": "0x2a28cc33492516116690a20d290f9922acbe0ed367ff52a6082154474c7f2971",
#         "slug": "will-the-fed-increase-interest-rates-by-50-bps-after-the-july-2026-meeting",
#         "endDate": "2026-07-29T00:00:00Z",
#         "startDate": "2026-03-20T00:12:57.861797Z",
#         "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powell+glasses1.png",
#         "description": "The FED interest rates are defined in this market by the upper bound of the target federal funds range. The decisions on the target federal funds range are made by the Federal Open Market Committee (FOMC) meetings.\n\nThis market will resolve to the amount of basis points the upper bound of the target federal funds rate is changed by versus the level it was prior to the Federal Reserve's July 2026 meeting.\n\nIf the target federal funds rate is changed to a level not expressed in the displayed options, the change will be rounded up to the nearest 25 and will resolve to the relevant bracket. (e.g. if there's a cut/increase of 12.5 bps it will be considered to be 25 bps)\n\nThe resolution source for this market is the FOMC\u2019s statement after its meeting scheduled for July 28-29, 2026 according to the official calendar: https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm.\n\nThe level and change of the target federal funds rate is also published at the official website of the Federal Reserve at https://www.federalreserve.gov/monetarypolicy/openmarket.htm.\n\nThis market may resolve as soon as the FOMC\u2019s statement for their July meeting with relevant data is issued. If no statement is released by the end date of the next scheduled meeting, this market will resolve to the \"No change\" bracket.",
#         "outcomes": "[\"Yes\", \"No\"]",
#         "outcomePrices": "[\"0\", \"1\"]",
#         "volume": "27556966.68968001",
#         "active": true,
#         "closed": true,
#         "marketMakerAddress": "",
#         "createdAt": "2026-03-19T20:51:50.722515Z",
#         "updatedAt": "2026-07-30T18:38:17.185797Z",
#         "closedTime": "2026-07-29 20:01:42+00",
#         "new": false,
#         "featured": false,
#         "submitted_by": "0x91430CaD2d3975766499717fA0D66A78D814E5c5",
#         "archived": false,
#         "resolvedBy": "0x69c47De9D4D3Dad79590d61b9e05918E03775f24",
#         "restricted": true,
#         "groupItemTitle": "50+ bps increase",
#         "groupItemThreshold": "4",
#         "questionID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3404",
#         "umaEndDate": "2026-07-29T20:01:42Z",
#         "enableOrderBook": true,
#         "orderPriceMinTickSize": 0.001,
#         "orderMinSize": 5,
#         "umaResolutionStatus": "resolved",
#         "volumeNum": 27556966.68968001,
#         "endDateIso": "2026-07-29",
#         "startDateIso": "2026-03-20",
#         "hasReviewedDates": true,
#         "clobTokenIds": "[\"55547507942649396203839937021705347989082320770224485499197798791654376614809\", \"82752177927542167404038816431416174971863195141383694610771473564093425601859\"]",
#         "comboStatus": "disabled",
#         "umaBond": "500",
#         "umaReward": "5",
#         "volumeClob": 27556966.68968001,
#         "makerBaseFee": 1000,
#         "takerBaseFee": 1000,
#         "customLiveness": 0,
#         "acceptingOrders": false,
#         "negRisk": true,
#         "negRiskMarketID": "0x40fd26ada6f086ebd83f34012327c0914d56154faf3fa36d912468c2532f3400",
#         "negRiskRequestID": "0x996b153c2fb0d970381f0a922076d9412f0c20d42c6526623474444754c1d1b7",
#         "ready": false,
#         "funded": false,
#         "acceptingOrdersTimestamp": "2026-03-20T00:11:35Z",
#         "cyom": false,
#         "pagerDutyNotificationEnabled": false,
#         "approved": true,
#         "rewardsMinSize": 100,
#         "rewardsMaxSpread": 2.5,
#         "spread": 0.001,
#         "automaticallyResolved": true,
#         "oneDayPriceChange": -0.002,
#         "oneWeekPriceChange": -0.008,
#         "oneMonthPriceChange": -0.004,
#         "lastTradePrice": 0.001,
#         "bestAsk": 0.001,
#         "automaticallyActive": true,
#         "clearBookOnStart": true,
#         "showGmpSeries": false,
#         "showGmpOutcome": false,
#         "manualActivation": false,
#         "negRiskOther": false,
#         "umaResolutionStatuses": "[\"proposed\"]",
#         "pendingDeployment": false,
#         "deploying": false,
#         "deployingTimestamp": "2026-03-20T00:09:52.85988Z",
#         "rfqEnabled": false,
#         "holdingRewardsEnabled": false,
#         "feesEnabled": true,
#         "requiresTranslation": false,
#         "feeType": "economics_fees",
#         "feeSchedule": {
#           "exponent": 1,
#           "rate": 0.05,
#           "takerOnly": true,
#           "rebateRate": 0.25
#         },
#         "version": "v1"
#       }
#     ],
#     "series": [
#       {
#         "id": "35",
#         "ticker": "fomc",
#         "slug": "fomc",
#         "title": "FOMC",
#         "seriesType": "single",
#         "recurrence": "monthly",
#         "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powel+stern.png",
#         "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/jerome+powel+stern.png",
#         "layout": "default",
#         "active": true,
#         "closed": false,
#         "archived": false,
#         "new": false,
#         "featured": false,
#         "restricted": true,
#         "publishedAt": "2023-03-22 19:17:35.835+00",
#         "createdBy": "15",
#         "updatedBy": "15",
#         "createdAt": "2023-02-03T22:02:38.864Z",
#         "updatedAt": "2026-08-17T19:16:53.87821Z",
#         "commentsEnabled": false,
#         "competitive": "0",
#         "volume24hr": 1801150.8714589998,
#         "volume": 36775058.60281402,
#         "liquidity": 4664487.11117,
#         "startDate": "2021-01-01T17:00:00Z",
#         "commentCount": 8673,
#         "requiresTranslation": false
#       }
#     ],
#     "tags": [
#       {
#         "id": "101800",
#         "label": "Economic Policy",
#         "slug": "economic-policy",
#         "forceShow": false,
#         "createdAt": "2025-02-06T18:05:50.554703Z",
#         "updatedAt": "2026-04-17T20:34:30.088167Z",
#         "requiresTranslation": false
#       },
#       {
#         "id": "100328",
#         "label": "Economy",
#         "slug": "economy",
#         "forceShow": false,
#         "createdAt": "2024-08-05T05:34:54.235643Z",
#         "updatedAt": "2026-04-17T20:29:06.948273Z",
#         "requiresTranslation": false
#       },
#       {
#         "id": "101550",
#         "label": "Jerome Powell",
#         "slug": "jerome-powell",
#         "createdAt": "2024-12-18T23:06:40.410115Z",
#         "updatedAt": "2026-04-17T17:26:03.169374Z",
#         "requiresTranslation": false
#       },
#       {
#         "id": "100478",
#         "label": "fomc",
#         "slug": "fomc",
#         "createdAt": "2024-09-18T16:39:12.895052Z",
#         "updatedAt": "2026-04-17T20:41:15.156214Z",
#         "requiresTranslation": false
#       },
#       {
#         "id": "159",
#         "label": "Fed",
#         "slug": "fed",
#         "forceShow": false,
#         "publishedAt": "2023-11-02 21:27:18.98+00",
#         "createdAt": "2023-11-02T21:27:18.986Z",
#         "updatedAt": "2026-04-17T21:09:42.963001Z",
#         "isCarousel": false,
#         "requiresTranslation": false
#       },
#       {
#         "id": "100196",
#         "label": "Fed Rates",
#         "slug": "fed-rates",
#         "forceShow": true,
#         "updatedAt": "2026-04-17T17:15:07.579162Z",
#         "requiresTranslation": false
#       },
#       {
#         "id": "2",
#         "label": "Politics",
#         "slug": "politics",
#         "forceShow": false,
#         "publishedAt": "2023-10-25 18:55:50.674+00",
#         "updatedBy": 13,
#         "createdAt": "2023-10-25T18:55:50.681Z",
#         "updatedAt": "2026-04-17T20:39:54.201881Z",
#         "forceHide": true,
#         "requiresTranslation": false
#       },
#       {
#         "id": "105614",
#         "label": "CPI Release",
#         "slug": "cpi-release",
#         "forceShow": false,
#         "createdAt": "2026-07-13T16:21:39.23125Z",
#         "updatedAt": "2026-07-13T16:25:05.4713Z",
#         "isCarousel": false,
#         "requiresTranslation": false
#       }
#     ],
#     "cyom": false,
#     "closedTime": "2026-07-29T20:06:41Z",
#     "showAllOutcomes": true,
#     "showMarketImages": false,
#     "automaticallyResolved": true,
#     "enableNegRisk": true,
#     "automaticallyActive": true,
#     "seriesSlug": "fomc",
#     "gmpChartMode": "default",
#     "negRiskAugmented": false,
#     "estimateValue": false,
#     "cumulativeMarkets": false,
#     "pendingDeployment": false,
#     "deploying": false,
#     "deployingTimestamp": "2026-03-20T00:08:25.356671Z",
#     "requiresTranslation": false,
#     "eventMetadata": {
#       "context_description": "Persistent inflation pressures from the May 2026 CPI report, which showed a 4.2% year-over-year rise driven by a 23.5% surge in energy costs amid Middle East tensions, have anchored trader expectations for the July 28-29 FOMC meeting. With the federal funds rate steady at 3.50%-3.75% following the June decision under new Chair Kevin Warsh, market-implied odds heavily favor no change at 79.5%, reflecting caution as June CPI data arrives July 14. Modest 19.4% pricing for a 25 basis point hike incorporates dot-plot signals that nine officials anticipate at least one increase this year, while negligible probabilities for cuts underscore limited downside risks given resilient labor markets and elevated Treasury yields. Geopolitical and data-dependent factors remain key swing elements before resolution.",
#       "context_requires_regen": true,
#       "context_updated_at": "2026-06-18T02:31:31.891Z"
#     },
#     "version": "v1"
#   }
# ]

# %%
event = data[0]

for market in event['markets']:
    print(market['groupItemTitle'])
# Out:
# 50+ bps decrease
# 25 bps decrease
# No change
# 25 bps increase
# 50+ bps increase

# %%
for market in event['markets']:
    if market['groupItemTitle'] == 'No change':
        target_market = market

# %%
condition_id = target_market['conditionId']
clob_token_ids = target_market['clobTokenIds']
clob_token_ids = json.loads(clob_token_ids)

print(condition_id)
print(clob_token_ids)
# Out:
# 0x8bf1c1536ecb1c08fe13c6b71e8ab1f58bf3461c4cb79f5f1679f869a06aef86
# ['111604417349377875799825956621596386269673370070912696668140891647145772186047', '36015050921127306245266044699797268780268172446856063291868548314968920497494']

# %%
yes_token_id = clob_token_ids[0]

clob_url = "https://clob.polymarket.com/prices-history"
params = {
    "market": yes_token_id,
    "interval": "max",
    "fidelity": 1
}

response = requests.get(clob_url, params=params)
history = response.json()

print(history)
# Out:
# {'history': [{'t': 1784316608, 'p': 0.9445}, {'t': 1784317205, 'p': 0.9445}, {'t': 1784317807, 'p': 0.944}, {'t': 1784318409, 'p': 0.9445}, {'t': 1784319007, 'p': 0.9435}, {'t': 1784319605, 'p': 0.9435}, {'t': 1784320208, 'p': 0.9435}, {'t': 1784320804, 'p': 0.9435}, {'t': 1784321405, 'p': 0.9435}, {'t': 1784322010, 'p': 0.9435}, {'t': 1784322606, 'p': 0.9445}, {'t': 1784323204, 'p': 0.9445}, {'t': 1784323809, 'p': 0.9445}, {'t': 1784324406, 'p': 0.9445}, {'t': 1784325005, 'p': 0.9445}, {'t': 1784325610, 'p': 0.9445}, {'t': 1784326209, 'p': 0.9445}, {'t': 1784326804, 'p': 0.9445}, {'t': 1784327408, 'p': 0.9445}, {'t': 1784328006, 'p': 0.9435}, {'t': 1784328606, 'p': 0.9435}, {'t': 1784329210, 'p': 0.9435}, {'t': 1784329805, 'p': 0.9435}, {'t': 1784330406, 'p': 0.9435}, {'t': 1784331010, 'p': 0.9435}, {'t': 1784331606, 'p': 0.9435}, {'t': 1784332206, 'p': 0.9435}, {'t': 1784332811, 'p': 0.9435}, {'t': 1784333405, 'p': 0.9435}, {'t': 1784334004, 'p': 0.9435}, {'t': 1784334608, 'p': 0.9435}, {'t': 1784335207, 'p': 0.9435}, {'t': 1784335806, 'p': 0.9435}, {'t': 1784336407, 'p': 0.9435}, {'t': 1784337005, 'p': 0.9435}, {'t': 1784337606, 'p': 0.9425}, {'t': 1784338205, 'p': 0.9425}, {'t': 1784338805, 'p': 0.9435}, {'t': 1784339404, 'p': 0.9435}, {'t': 1784340007, 'p': 0.9435}, {'t': 1784340606, 'p': 0.9435}, {'t': 1784341204, 'p': 0.9435}, {'t': 1784341818, 'p': 0.9425}, {'t': 1784342406, 'p': 0.9425}, {'t': 1784343006, 'p': 0.9425}, {'t': 1784343611, 'p': 0.9425}, {'t': 1784344204, 'p': 0.9425}, {'t': 1784344804, 'p': 0.9425}, {'t': 1784345407, 'p': 0.9425}, {'t': 1784346005, 'p': 0.9425}, {'t': 1784346606, 'p': 0.9425}, {'t': 1784347207, 'p': 0.9425}, {'t': 1784347806, 'p': 0.9445}, {'t': 1784348406, 'p': 0.9445}, {'t': 1784349008, 'p': 0.9445}, {'t': 1784349605, 'p': 0.9445}, {'t': 1784350207, 'p': 0.9465}, {'t': 1784350808, 'p': 0.946}, {'t': 1784351406, 'p': 0.946}, {'t': 1784352006, 'p': 0.9455}, {'t': 1784352607, 'p': 0.9455}, {'t': 1784353205, 'p': 0.9455}, {'t': 1784353805, 'p': 0.9455}, {'t': 1784354411, 'p': 0.9455}, {'t': 1784355013, 'p': 0.9455}, {'t': 1784355605, 'p': 0.9455}, {'t': 1784356207, 'p': 0.9455}, {'t': 1784356805, 'p': 0.9465}, {'t': 1784357404, 'p': 0.9465}, {'t': 1784358011, 'p': 0.9465}, {'t': 1784358604, 'p': 0.9465}, {'t': 1784359208, 'p': 0.9465}, {'t': 1784359807, 'p': 0.9475}, {'t': 1784360406, 'p': 0.9475}, {'t': 1784361006, 'p': 0.9475}, {'t': 1784361607, 'p': 0.9475}, {'t': 1784362204, 'p': 0.9475}, {'t': 1784362806, 'p': 0.9475}, {'t': 1784363408, 'p': 0.9475}, {'t': 1784364009, 'p': 0.9475}, {'t': 1784364605, 'p': 0.9475}, {'t': 1784365214, 'p': 0.9475}, {'t': 1784365807, 'p': 0.9475}, {'t': 1784366406, 'p': 0.9475}, {'t': 1784367007, 'p': 0.9475}, {'t': 1784367604, 'p': 0.9475}, {'t': 1784368204, 'p': 0.9475}, {'t': 1784368808, 'p': 0.9475}, {'t': 1784369409, 'p': 0.9475}, {'t': 1784370006, 'p': 0.9475}, {'t': 1784370607, 'p': 0.9475}, {'t': 1784371205, 'p': 0.9475}, {'t': 1784371804, 'p': 0.9475}, {'t': 1784372411, 'p': 0.9475}, {'t': 1784373006, 'p': 0.9475}, {'t': 1784373605, 'p': 0.9475}, {'t': 1784374208, 'p': 0.9475}, {'t': 1784374805, 'p': 0.9475}, {'t': 1784375406, 'p': 0.9475}, {'t': 1784376025, 'p': 0.9475}, {'t': 1784376608, 'p': 0.9475}, {'t': 1784377209, 'p': 0.9475}, {'t': 1784377808, 'p': 0.9475}, {'t': 1784378405, 'p': 0.9475}, {'t': 1784379007, 'p': 0.9475}, {'t': 1784379609, 'p': 0.9475}, {'t': 1784380206, 'p': 0.9475}, {'t': 1784380806, 'p': 0.9475}, {'t': 1784381409, 'p': 0.9475}, {'t': 1784382004, 'p': 0.9475}, {'t': 1784382609, 'p': 0.9475}, {'t': 1784383209, 'p': 0.9475}, {'t': 1784383805, 'p': 0.9475}, {'t': 1784384406, 'p': 0.9475}, {'t': 1784385008, 'p': 0.9475}, {'t': 1784385604, 'p': 0.9475}, {'t': 1784386209, 'p': 0.9475}, {'t': 1784386818, 'p': 0.9475}, {'t': 1784387407, 'p': 0.9475}, {'t': 1784388021, 'p': 0.9475}, {'t': 1784388607, 'p': 0.9475}, {'t': 1784389206, 'p': 0.9475}, {'t': 1784389805, 'p': 0.9475}, {'t': 1784390409, 'p': 0.9475}, {'t': 1784391007, 'p': ...

# %%
df = pd.DataFrame(history['history'])
df['datetime'] = pd.to_datetime(df['t'], unit='s')
df['datetime'] = df['datetime'].dt.tz_localize('UTC').dt.tz_convert('America/New_York')
df.head()
# Out:
#             t       p                  datetime
# 0  1784316608  0.9445 2026-07-17 15:30:08-04:00
# 1  1784317205  0.9445 2026-07-17 15:40:05-04:00
# 2  1784317807  0.9440 2026-07-17 15:50:07-04:00
# 3  1784318409  0.9445 2026-07-17 16:00:09-04:00
# 4  1784319007  0.9435 2026-07-17 16:10:07-04:00

# %%
window_df = df[(df['datetime'] >= '2026-07-29 12:00:00') & (df['datetime'] <= '2026-07-29 16:00:00')].copy()
window_df = window_df.rename(columns={'t': 'unix_timestamp', 'p': 'implied_probability_no_change'})
print(window_df.head())
print(window_df.tail())
# Out:
#       unix_timestamp  implied_probability_no_change                  datetime
# 1668      1785341444                         0.7245 2026-07-29 12:10:44-04:00
# 1669      1785342036                         0.7275 2026-07-29 12:20:36-04:00
# 1670      1785343235                         0.7405 2026-07-29 12:40:35-04:00
# 1671      1785343829                         0.7465 2026-07-29 12:50:29-04:00
# 1672      1785345038                         0.7425 2026-07-29 13:10:38-04:00
#       unix_timestamp  implied_probability_no_change                  datetime
# 1682      1785352210                         0.9995 2026-07-29 15:10:10-04:00
# 1683      1785352812                         0.9995 2026-07-29 15:20:12-04:00
# 1684      1785353419                         0.9995 2026-07-29 15:30:19-04:00
# 1685      1785354012                         0.9995 2026-07-29 15:40:12-04:00
# 1686      1785354611                         0.9995 2026-07-29 15:50:11-04:00

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(window_df['datetime'], window_df['implied_probability_no_change'])
ax.set_title('polymarket: no change probability around july 2026 fomc announcement')
ax.set_xlabel('time (et)')
ax.set_ylabel('implied probability (no change)')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M', tz=window_df['datetime'].dt.tz))
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
start = datetime.datetime(2026, 7, 1)
end = datetime.datetime(2026, 7, 28)

effr_full = web.DataReader('EFFR', 'fred', start, end)
r_before = effr_full['EFFR'].mean()

print(effr_full)
print(r_before)
# Out:
#             EFFR
# DATE
# 2026-07-01  3.63
# 2026-07-02  3.63
# 2026-07-03  3.63
# 2026-07-06  3.63
# 2026-07-07  3.63
# 2026-07-08  3.62
# 2026-07-09  3.62
# 2026-07-10  3.62
# 2026-07-13  3.62
# 2026-07-14  3.63
# 2026-07-15  3.63
# 2026-07-16  3.63
# 2026-07-17  3.63
# 2026-07-20  3.63
# 2026-07-21  3.63
# 2026-07-22  3.63
# 2026-07-23  3.63
# 2026-07-24  3.63
# 2026-07-27  3.63
# 2026-07-28  3.63
# 3.6279999999999992

# %%
all_probabilities = {}

for market in event['markets']:
    outcome_name = market['groupItemTitle']
    token_ids = json.loads(market['clobTokenIds'])
    yes_token_id_loop = token_ids[0]

    params = {
        "market": yes_token_id_loop,
        "interval": "max",
        "fidelity": 1
    }
    response = requests.get(clob_url, params=params)
    history_loop = response.json()

    outcome_df = pd.DataFrame(history_loop['history'])
    outcome_df['datetime'] = pd.to_datetime(outcome_df['t'], unit='s')
    outcome_df['datetime'] = outcome_df['datetime'].dt.tz_localize('UTC').dt.tz_convert('America/New_York')

    all_probabilities[outcome_name] = outcome_df

print(all_probabilities.keys())
# Out:
# dict_keys(['50+ bps decrease', '25 bps decrease', 'No change', '25 bps increase', '50+ bps increase'])

# %%
windowed_outcomes = {}
for outcome_name, outcome_df in all_probabilities.items():
    windowed = outcome_df[(outcome_df['datetime'] >= '2026-07-29 12:00:00') & (outcome_df['datetime'] <= '2026-07-29 16:00:00')].copy()
    windowed_outcomes[outcome_name] = windowed

for name, wdf in windowed_outcomes.items():
    print(name, len(wdf), 'rows')
# Out:
# 50+ bps decrease 24 rows
# 25 bps decrease 23 rows
# No change 19 rows
# 25 bps increase 23 rows
# 50+ bps increase 19 rows

# %%
combined = pd.DataFrame()

for outcome_name, wdf in windowed_outcomes.items():
    s = wdf.set_index('datetime')['p'].resample('1min').last().ffill()
    combined[outcome_name] = s

combined = combined.dropna()
print(combined.head())
print(combined.tail())
# Out:
#                            50+ bps decrease  25 bps decrease  No change  \
# datetime
# 2026-07-29 12:10:00-04:00            0.0005           0.0025     0.7245
# 2026-07-29 12:11:00-04:00            0.0005           0.0025     0.7245
# 2026-07-29 12:12:00-04:00            0.0005           0.0025     0.7245
# 2026-07-29 12:13:00-04:00            0.0005           0.0025     0.7245
# 2026-07-29 12:14:00-04:00            0.0005           0.0025     0.7245
#
#                            25 bps increase  50+ bps increase
# datetime
# 2026-07-29 12:10:00-04:00           0.2665            0.0045
# 2026-07-29 12:11:00-04:00           0.2665            0.0045
# 2026-07-29 12:12:00-04:00           0.2665            0.0045
# 2026-07-29 12:13:00-04:00           0.2665            0.0045
# 2026-07-29 12:14:00-04:00           0.2665            0.0045
#                            50+ bps decrease  25 bps decrease  No change  \
# datetime
# 2026-07-29 15:46:00-04:00            0.0005           0.0005     0.9995
# 2026-07-29 15:47:00-04:00            0.0005           0.0005     0.9995
# 2026-07-29 15:48:00-04:00            0.0005           0.0005     0.9995
# 2026-07-29 15:49:00-04:00            0.0005           0.0005     0.9995
# 2026-07-29 15:50:00-04:00            0.0005           0.0005     0.9995
#
#                            25 bps increase  50+ bps increase
# datetime
# 2026-07-29 15:46:00-04:00           0.0005            0.0005
# 2026-07-29 15:47:00-04:00           0.0005            0.0005
# 2026-07-29 15:48:00-04:00           0.0005            0.0005
# 2026-07-29 15:49:00-04:00           0.0005            0.0005
# 2026-07-29 15:50:00-04:00           0.0005            0.0005

# %%
combined['r_after'] = (
    combined['50+ bps decrease'] * (r_before - 0.50) +
    combined['25 bps decrease'] * (r_before - 0.25) +
    combined['No change'] * r_before +
    combined['25 bps increase'] * (r_before + 0.25) +
    combined['50+ bps increase'] * (r_before + 0.50)
)

print(combined[['r_after']].head())
print(combined[['r_after']].tail())
# Out:
#                             r_after
# datetime
# 2026-07-29 12:10:00-04:00  3.690558
# 2026-07-29 12:11:00-04:00  3.690558
# 2026-07-29 12:12:00-04:00  3.690558
# 2026-07-29 12:13:00-04:00  3.690558
# 2026-07-29 12:14:00-04:00  3.690558
#                             r_after
# datetime
# 2026-07-29 15:46:00-04:00  3.633442
# 2026-07-29 15:47:00-04:00  3.633442
# 2026-07-29 15:48:00-04:00  3.633442
# 2026-07-29 15:49:00-04:00  3.633442
# 2026-07-29 15:50:00-04:00  3.633442

# %%
zq_df = pd.read_csv('zq_july29.csv')
zq_df['datetime'] = pd.to_datetime(zq_df['time'], unit='s')
zq_df['datetime'] = zq_df['datetime'].dt.tz_localize('UTC').dt.tz_convert('America/New_York')
zq_df.head()
# Out:
#          time   open   high    low  close  Volume                  datetime
# 0  1783967820  96.27  96.27  96.27  96.27     481 2026-07-13 14:37:00-04:00
# 1  1783967880  96.27  96.27  96.27  96.27      11 2026-07-13 14:38:00-04:00
# 2  1783968060  96.27  96.27  96.27  96.27     640 2026-07-13 14:41:00-04:00
# 3  1783968120  96.27  96.27  96.27  96.27     199 2026-07-13 14:42:00-04:00
# 4  1783968180  96.27  96.27  96.27  96.27     139 2026-07-13 14:43:00-04:00

# %%
zq_window = zq_df[(zq_df['datetime'] >= '2026-07-29 12:00:00') & (zq_df['datetime'] <= '2026-07-29 16:00:00')].copy()
print(zq_window.head())
print(zq_window.tail())
# Out:
#             time    open    high     low   close  Volume  \
# 4907  1785340800  96.285  96.285  96.285  96.285    1251
# 4908  1785340860  96.285  96.285  96.285  96.285      57
# 4909  1785340920  96.285  96.285  96.285  96.285     560
# 4910  1785340980  96.285  96.285  96.285  96.285     261
# 4911  1785341100  96.285  96.285  96.285  96.285      42
#
#                       datetime
# 4907 2026-07-29 12:00:00-04:00
# 4908 2026-07-29 12:01:00-04:00
# 4909 2026-07-29 12:02:00-04:00
# 4910 2026-07-29 12:03:00-04:00
# 4911 2026-07-29 12:05:00-04:00
#             time    open    high     low   close  Volume  \
# 5111  1785354840  96.370  96.370  96.370  96.370       8
# 5112  1785354900  96.365  96.365  96.365  96.365      31
# 5113  1785354960  96.365  96.365  96.365  96.365      15
# 5114  1785355080  96.365  96.365  96.365  96.365     243
# 5115  1785355140  96.365  96.365  96.365  96.365      99
#
#                       datetime
# 5111 2026-07-29 15:54:00-04:00
# 5112 2026-07-29 15:55:00-04:00
# 5113 2026-07-29 15:56:00-04:00
# 5114 2026-07-29 15:58:00-04:00
# 5115 2026-07-29 15:59:00-04:00

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(zq_window['datetime'], zq_window['close'])
ax.set_title('fed futures price around july 2026 fomc announcement')
ax.set_xlabel('time (et)')
ax.set_ylabel('futures price (close)')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M', tz=zq_window['datetime'].dt.tz))
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
zq_window['implied_rate'] = 100 - zq_window['close']
print(zq_window[['datetime', 'close', 'implied_rate']].head())
print(zq_window[['datetime', 'close', 'implied_rate']].tail())
# Out:
#                       datetime   close  implied_rate
# 4907 2026-07-29 12:00:00-04:00  96.285         3.715
# 4908 2026-07-29 12:01:00-04:00  96.285         3.715
# 4909 2026-07-29 12:02:00-04:00  96.285         3.715
# 4910 2026-07-29 12:03:00-04:00  96.285         3.715
# 4911 2026-07-29 12:05:00-04:00  96.285         3.715
#                       datetime   close  implied_rate
# 5111 2026-07-29 15:54:00-04:00  96.370         3.630
# 5112 2026-07-29 15:55:00-04:00  96.365         3.635
# 5113 2026-07-29 15:56:00-04:00  96.365         3.635
# 5114 2026-07-29 15:58:00-04:00  96.365         3.635
# 5115 2026-07-29 15:59:00-04:00  96.365         3.635
